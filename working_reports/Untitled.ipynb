# %%
import pandas as pd

# %%
df = pd.read_csv("./featureselection.csv")

# %%
df['System'] = df["System"] / 6.6842*10
df['Station'] = df['Station'] / 6.3176*10

# %%
df['Feat'].value_counts()
# Out:
# near_hospitality         10
# parking                   8
# 30net_medical             6
# near_university           6
# near_entertainment        5
# near_pop_old              5
# 15net_hunits_attached     5
# 15net_hunits_old          5
# 15net_university          4
# near_emp_pay              4
# 15net_hunits_medium       4
# 30net_hunits_large        4
# near_employment           4
# near_hunits_owner         3
# near_medical              3
# 15net_hospitality         3
# near_hunits_attached      3
# 30net_hunits_medium       2
# near_labor_force          2
# near_population           2
# near_family               2
# near_business             2
# near_hunits_detached      2
# 15net_hunits_vacant       2
# near_hunits_large         2
# 30net_hospitality         2
# 15net_medical             2
# near_hunits_new           2
# 30net_entertainment       2
# 15net_employed            2
# near_pop_rich             1
# 30net_emp_pay             1
# 15net_pop_child           1
# ...

# %%
df.groupby('Feat')[['System', 'Station']].sum()
# Out:
#                           System    Station
# Feat
# 15net_bachelors         0.000000   0.000000
# 15net_emp_pay           0.000000   0.000000
# 15net_employed          1.478861   1.582880
# 15net_entertainment     1.496065   1.489015
# 15net_hospitality       1.606924   1.603774
# 15net_household         0.000000   0.000000
# 15net_hunits_attached   2.807217   3.047676
# 15net_hunits_medium     2.072051   2.074522
# 15net_hunits_old        4.953024   4.853584
# 15net_hunits_vacant     1.200293   1.443903
# 15net_medical           1.349451   1.264088
# 15net_pop_child         1.436821   1.275168
# 15net_university        5.017504   5.001425
# 30net_emp_pay           1.436821   1.275168
# 30net_entertainment     2.845516   2.753102
# 30net_hospitality       1.200293   1.443903
# 30net_hunits_detached   0.735167   0.973154
# 30net_hunits_large      3.521439   3.512410
# 30net_hunits_medium     0.735167   0.973154
# 30net_hunits_old        1.431585   1.341174
# ...
