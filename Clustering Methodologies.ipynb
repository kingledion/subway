# %%
from regression import citylist, loadData
import statsmodels.api as sm, itertools, networkx as nx, community, numpy as np
from sklearn.cluster import affinity_propagation, spectral_clustering
from sklearn.ensemble import RandomForestRegressor

# %%
df = loadData(citylist)
cols = list(df.columns.difference(['lat', 'lon', 'name', 'riders']))
combos = [(a, b) for a, b in itertools.product(cols, cols) if a != b]

# %%
data = []
for a, b in combos:
#    a, b = 'near_population', 'near_family'
    y = df[a]
    X = sm.add_constant(df[b])
    result = sm.OLS(y, X).fit()
    rs = result.rsquared
    data.append((a, b, rs))

# %%
adj = np.zeros([len(cols), len(cols)])
for istr, jstr, score in data:
    i = cols.index(istr)
    j = cols.index(jstr)
    adj[i][j] = score
    adj[j][i] = score

# %%
centers, labels = affinity_propagation(adj)
clusters = {}
for name, c in zip(cols, labels):
    if c in clusters:
        clusters[c].append([name])
    else:
        clusters[c] = [name]
for c, names in clusters.items():
    print(c, names)
# Out:
# 0 ['15net_business', ['15net_emp_pay'], ['15net_employment'], ['15net_entertainment'], ['15net_finance'], ['15net_hospitality'], ['15net_hunits_new']]
# 1 ['15net_bachelors', ['15net_emp_full_time'], ['15net_employed'], ['15net_family'], ['15net_household'], ['15net_hunits'], ['15net_hunits_attached'], ['15net_hunits_large'], ['15net_hunits_medium'], ['15net_hunits_old'], ['15net_hunits_owner'], ['15net_hunits_renter'], ['15net_hunits_vacant'], ['15net_labor_force'], ['15net_pop_old'], ['15net_pop_rich'], ['15net_population']]
# 2 ['15net_house_w_child', ['15net_hunits_detached'], ['15net_pop_child'], ['15net_pop_poor'], ['30net_hunits_detached']]
# 3 ['30net_business', ['30net_emp_pay'], ['30net_employment'], ['30net_entertainment'], ['30net_finance'], ['30net_hospitality']]
# 4 ['30net_bachelors', ['30net_emp_full_time'], ['30net_employed'], ['30net_family'], ['30net_house_w_child'], ['30net_household'], ['30net_hunits'], ['30net_hunits_attached'], ['30net_hunits_large'], ['30net_hunits_medium'], ['30net_hunits_new'], ['30net_hunits_old'], ['30net_hunits_owner'], ['30net_hunits_renter'], ['30net_hunits_vacant'], ['30net_labor_force'], ['30net_pop_child'], ['30net_pop_old'], ['30net_pop_poor'], ['30net_pop_rich'], ['30net_population']]
# 5 ['15net_medical', ['15net_university'], ['30net_medical'], ['30net_university'], ['60net_medical'], ['60net_university']]
# 6 ['60net_bachelors', ['60net_business'], ['60net_emp_pay'], ['60net_employment'], ['60net_finance'], ['60net_hospitality'], ['60net_hunits_attached'], ['60net_hunits_medium'], ['60net_hunits_new'], ['60net_hunits_old'], ['60net_hunits_owner'], ['60net_hunits_vacant'], ['60net_pop_rich']]
# 7 ['60net_emp_full_time', ['60net_employed'], ['60net_entertainment'], ['60net_family'], ['60net_house_w_child'], ['60net_household'], ['60net_hunits'], ['60net_hunits_detached'], ['60net_hunits_large'], ['60net_hunits_renter'], ['60net_labor_force'], ['60net_pop_child'], ['60net_pop_old'], ['60net_pop_poor'], ['60net_population']]
# 8 ['near_business', ['near_emp_pay'], ['near_employment'], ['near_entertainment'], ['near_finance'], ['near_hospitality']]
# 9 ['near_family', ['near_house_w_child'], ['near_pop_child'], ['near_pop_poor'], ['near_population']]
# 10 ['near_emp_full_time', ['near_employed'], ['near_household'], ['near_hunits'], ['near_hunits_large'], ['near_hunits_renter'], ['near_hunits_vacant'], ['near_labor_force'], ['near_pop_old']]
# 11 ['near_hunits_detached', ['walk_hunits_detached']]
# 12 ['near_hunits_attached', ['near_hunits_medium'], ['near_hunits_old'], ['walk_hunits_attached']]
# 13 ['near_bachelors', ['near_hunits_new'], ['near_hunits_owner'], ['near_pop_rich']]
# 14 ['parking']
# 15 ['walk_business', ['walk_emp_pay'], ['walk_employment'], ['walk_entertainment'], ['walk_finance'], ['walk_hospitality'], ['walk_hunits_new']]
# 16 ['walk_bachelors', ['walk_emp_full_time'], ['walk_employed'], ['walk_family'], ['walk_household'], ['walk_hunits'], ['walk_hunits_large'], ['walk_hunits_medium'], ['walk_hunits_old'], ['walk_hunits_owner'], ['walk_hunits_renter'], ['walk_hunits_vacant'], ['walk_labor_force'], ['walk_pop_old'], ['walk_pop_rich'], ['walk_population']]
# 17 ['near_medical', ['near_university'], ['walk_medical'], ['walk_university']]
# 18 ['walk_house_w_child', ['walk_pop_child'], ['walk_pop_poor']]

# %%
labels = spectral_clustering(adj)
for name, c in zip(cols, labels):
    if c in clusters:
        clusters[c].append([name])
    else:
        clusters[c] = [name]
for c, names in clusters.items():
    print(c, names)
# Out:
# 0 ['15net_business', ['15net_emp_pay'], ['15net_employment'], ['15net_entertainment'], ['15net_finance'], ['15net_hospitality'], ['15net_hunits_new'], ['15net_medical'], ['15net_university'], ['30net_medical'], ['30net_university'], ['60net_medical'], ['60net_university'], ['near_medical'], ['near_university'], ['parking'], ['walk_medical'], ['walk_university']]
# 1 ['15net_bachelors', ['15net_emp_full_time'], ['15net_employed'], ['15net_family'], ['15net_household'], ['15net_hunits'], ['15net_hunits_attached'], ['15net_hunits_large'], ['15net_hunits_medium'], ['15net_hunits_old'], ['15net_hunits_owner'], ['15net_hunits_renter'], ['15net_hunits_vacant'], ['15net_labor_force'], ['15net_pop_old'], ['15net_pop_rich'], ['15net_population'], ['near_bachelors'], ['near_emp_full_time'], ['near_employed'], ['near_household'], ['near_hunits'], ['near_hunits_large'], ['near_hunits_medium'], ['near_hunits_new'], ['near_hunits_old'], ['near_hunits_owner'], ['near_hunits_renter'], ['near_hunits_vacant'], ['near_labor_force'], ['near_pop_old'], ['near_pop_rich']]
# 2 ['15net_house_w_child', ['15net_hunits_detached'], ['15net_pop_child'], ['15net_pop_poor'], ['30net_hunits_detached'], ['15net_bachelors'], ['15net_business'], ['15net_emp_pay'], ['15net_employment'], ['15net_entertainment'], ['15net_finance'], ['15net_hospitality'], ['15net_hunits_attached'], ['15net_hunits_medium'], ['15net_hunits_new'], ['15net_hunits_owner'], ['15net_hunits_vacant'], ['15net_pop_rich'], ['30net_bachelors'], ['30net_business'], ['30net_emp_full_time'], ['30net_emp_pay'], ['30net_employed'], ['30net_employment'], ['30net_entertainment'], ['30net_finance'], ['30net_hospitality'], ['30net_household'], ['30net_hunits'], ['30net_hunits_attached'], ['30net_hunits_large'], ['30net_hunits_medium'], ['30net_hunits_new'], ['30net_hunits_old'], ['30net_hunits_owner'], ['30net_hunits_renter'], ['30net_hunits_vacant'], ['30net_labor_force'], ['30net_pop_old'], ['30net_pop_rich']]
# 3 ['30net_business', ['30net_emp_pay'], ['30net_employment'], ['30net_entertainment'], ['30net_finance'], ['30net_hospitality'], ['15net_hunits_old'], ['walk_bachelors'], ['walk_emp_full_time'], ['walk_employed'], ['walk_family'], ['walk_house_w_child'], ['walk_household'], ['walk_hunits'], ['walk_hunits_large'], ['walk_hunits_medium'], ['walk_hunits_old'], ['walk_hunits_owner'], ['walk_hunits_renter'], ['walk_hunits_vacant'], ['walk_labor_force'], ['walk_pop_old'], ['walk_pop_poor'], ['walk_pop_rich'], ['walk_population']]
# 4 ['30net_bachelors', ['30net_emp_full_time'], ['30net_employed'], ['30net_family'], ['30net_house_w_child'], ['30net_household'], ['30net_hunits'], ['30net_hunits_attached'], ['30net_hunits_large'], ['30net_hunits_medium'], ['30net_hunits_new'], ['30net_hunits_old'], ['30net_hunits_owner'], ['30net_hunits_renter'], ['30net_hunits_vacant'], ['30net_labor_force'], ['30net_pop_child'], ['30net_pop_old'], ['30net_pop_poor'], ['30net_pop_rich'], ['30net_population'], ['15net_emp_full_time'], ['15net_employed'], ['15net_family'], ['15net_house_w_child'], ['15net_household'], ['15net_hunits'], ['15net_hunits_large'], ['15net_hunits_renter'], ['15net_labor_force'], ['15net_pop_child'], ['15net_pop_old'], ['15net_pop_poor'], ['15net_population'], ['30net_family'], ['30net_house_w_child'], ['30net_hunits_detached'], ['30net_pop_child'], ['30net_pop_poor'], ['30net_population'], ['60net_hunits_detached'], ['60net_pop_poor']]
# 5 ['15net_medical', ['15net_university'], ['30net_medical'], ['30net_university'], ['60net_medical'], ['60net_university'], ['near_business'], ['near_emp_pay'], ['near_employment'], ['near_entertainment'], ['near_finance'], ['near_hospitality'], ['walk_business'], ['walk_emp_pay'], ['walk_employment'], ['walk_entertainment'], ['walk_finance'], ['walk_hospitality'], ['walk_hunits_new']]
# 6 ['60net_bachelors', ['60net_business'], ['60net_emp_pay'], ['60net_employment'], ['60net_finance'], ['60net_hospitality'], ['60net_hunits_attached'], ['60net_hunits_medium'], ['60net_hunits_new'], ['60net_hunits_old'], ['60net_hunits_owner'], ['60net_hunits_vacant'], ['60net_pop_rich'], ['60net_bachelors'], ['60net_business'], ['60net_emp_full_time'], ['60net_emp_pay'], ['60net_employed'], ['60net_employment'], ['60net_entertainment'], ['60net_family'], ['60net_finance'], ['60net_hospitality'], ['60net_house_w_child'], ['60net_household'], ['60net_hunits'], ['60net_hunits_attached'], ['60net_hunits_large'], ['60net_hunits_medium'], ['60net_hunits_new'], ['60net_hunits_old'], ['60net_hunits_owner'], ['60net_hunits_renter'], ['60net_hunits_vacant'], ['60net_labor_force'], ['60net_pop_child'], ['60net_pop_old'], ['60net_pop_rich'], ['60net_population'], ['walk_hunits_attached']]
# 7 ['60net_emp_full_time', ['60net_employed'], ['60net_entertainment'], ['60net_family'], ['60net_house_w_child'], ['60net_household'], ['60net_hunits'], ['60net_hunits_detached'], ['60net_hunits_large'], ['60net_hunits_renter'], ['60net_labor_force'], ['60net_pop_child'], ['60net_pop_old'], ['60net_pop_poor'], ['60net_population'], ['15net_hunits_detached'], ['near_family'], ['near_house_w_child'], ['near_hunits_attached'], ['near_hunits_detached'], ['near_pop_child'], ['near_pop_poor'], ['near_population'], ['walk_hunits_detached'], ['walk_pop_child']]
# 8 ['near_business', ['near_emp_pay'], ['near_employment'], ['near_entertainment'], ['near_finance'], ['near_hospitality']]
# 9 ['near_family', ['near_house_w_child'], ['near_pop_child'], ['near_pop_poor'], ['near_population']]
# 10 ['near_emp_full_time', ['near_employed'], ['near_household'], ['near_hunits'], ['near_hunits_large'], ['near_hunits_renter'], ['near_hunits_vacant'], ['near_labor_force'], ['near_pop_old']]
# 11 ['near_hunits_detached', ['walk_hunits_detached']]
# 12 ['near_hunits_attached', ['near_hunits_medium'], ['near_hunits_old'], ['walk_hunits_attached']]
# 13 ['near_bachelors', ['near_hunits_new'], ['near_hunits_owner'], ['near_pop_rich']]
# 14 ['parking']
# 15 ['walk_business', ['walk_emp_pay'], ['walk_employment'], ['walk_entertainment'], ['walk_finance'], ['walk_hospitality'], ['walk_hunits_new']]
# 16 ['walk_bachelors', ['walk_emp_full_time'], ['walk_employed'], ['walk_family'], ['walk_household'], ['walk_hunits'], ['walk_hunits_large'], ['walk_hunits_medium'], ['walk_hunits_old'], ['walk_hunits_owner'], ['walk_hunits_renter'], ['walk_hunits_vacant'], ['walk_labor_force'], ['walk_pop_old'], ['walk_pop_rich'], ['walk_population']]
# 17 ['near_medical', ['near_university'], ['walk_medical'], ['walk_university']]
# 18 ['walk_house_w_child', ['walk_pop_child'], ['walk_pop_poor']]

# %%
result = AgglomerativeClustering(n_clusters=4).fit(adj)
part_agg = {}
for part, name in zip(result.fit_predict(adj), cols):
    if part in part_agg:
        part_agg[part].append(name)
    else:
        part_agg[part] = [name]
# Out:
# /usr/local/lib/python3.5/dist-packages/scipy/cluster/hierarchy.py:471: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %%
nodes_part = community.best_partition(G, weight='weight')
part_louvain = {}
for k, v in nodes_part.items():
    if v in part_louvain:
        part_louvain[v].append(k)
    else:
        part_louvain[v] = [k]

# %%
result = KMeans(n_clusters=4).fit(adj)
part_kmeans = {}
for part, name in zip(result.predict(adj), cols):
    if part in part_kmeans:
        part_kmeans[part].append(name)
    else:
        part_kmeans[part] = [name]

# %%
output = []
for i in range(4):
    for j in range(4):
        for k in range(4):
            comlen = len(set(part_kmeans[i]) & set(part_louvain[j]) & set(part_agg[k]))
            avglen = len(part_kmeans[i])+len(part_louvain[j]) + len(part_agg[k])
            output.append((i, j, k, format(comlen*2/avglen)))
#for i, j, k, score in sorted(output, key = lambda x: x[3], reverse = True):
#    print(i, j, k, score)

# %%
row = adj[0]
rf = RandomForestRegressor()
rf.fit(df[cols], df['riders'])
featScore = {name: score for score, name in zip(rf.feature_importances_, cols)}

# %%
workinglist = []
for i, name, row in zip(range(len(cols)), cols, adj):
    maxIndex = list(row).index(max(row))
    highInds = [cols[i] for i,x in enumerate(row) if x > 0.99]
    minScore = min([featScore[x] for x in highInds]) if highInds else 0
    workinglist.append((name, featScore[name], len(highInds), minScore, featScore[name]<minScore))

# %%
rcols = [x for x in cols]
radj = np.array(adj)

# %%
sorted(workinglist, key=lambda x: x[4], reverse=True)
# Out:
# [('15net_hunits', 0.00026336082820744568, 1, 0.0019689980499935258, True),
#  ('15net_labor_force', 0.00041193117738682315, 2, 0.0010508059390040038, True),
#  ('30net_hunits', 2.8711893337580935e-05, 2, 0.000146978083384718, True),
#  ('30net_labor_force', 0.00010440695566416357, 3, 0.000146978083384718, True),
#  ('30net_pop_rich', 0.00028799923705843695, 1, 0.001146499088693286, True),
#  ('30net_population', 0.00013163538459463393, 1, 0.0011910796363626534, True),
#  ('60net_hunits', 3.2045386832697929e-05, 2, 6.6787926549970289e-05, True),
#  ('60net_pop_rich', 1.976004044229574e-05, 2, 0.00011314609507415014, True),
#  ('near_employed', 0.0012475036599142854, 1, 0.0041732792569205814, True),
#  ('near_hunits', 0.0024649207744563608, 1, 0.016070561388668712, True),
#  ('walk_household', 0.0016135731308468502, 1, 0.0097343576285956294, True),
#  ('walk_labor_force', 0.0039010567639515851, 1, 0.0040884198390042656, True),
#  ('15net_bachelors', 0.018687412713852502, 0, 0, False),
#  ('15net_business', 0.057588929182885204, 0, 0, False),
#  ('15net_emp_full_time',
#   0.0033944307112565289,
#   2,
#   0.00041193117738682315,
#   False),
#  ('15net_emp_pay', 0.04129631779178413, 0, 0, False),
#  ('15net_employed', 0.0010508059390040038, 2, 0.00041193117738682315, False),
#  ('15net_employment', 0.011985922261742266, 0, 0, False),
#  ('15net_entertainment', 0.00072046636160063421, 0, 0, False),
#  ('15net_family', 0.11094615093083129, 0, 0, False),
#  ('15net_finance', 0.00069241604279280528, 0, 0, False),
#  ('15net_hospitality', 0.0074029890243698365, 0, 0, False),
#  ('15net_house_w_child', 0.10515499185326942, 0, 0, False),
#  ('15net_household', 0.0019689980499935258, 1, 0.00026336082820744568, False),
#  ('15net_hunits_attached', 0.041279972711092447, 0, 0, False),
#  ('15net_hunits_detached', 0.016948726390444535, 0, 0, False),
#  ('15net_hunits_large', 0.0026236024352667433, 0, 0, False),
#  ('15net_hunits_medium', 0.0044407258644644058, 0, 0, False),
#  ('15net_hunits_new', 0.0013925518192157531, 0, 0, False),
#  ('15net_hunits_old', 0.00023935677491512507, 0, 0, False),
#  ('15net_hunits_owner', 0.00075599987464281394, 0, 0, False),
#  ('15net_hunits_renter', 0.0019337086855314711, 0, 0, False),
#  ('15net_hunits_vacant', 0.001686737542474534, 0, 0, False),
#  ('15net_medical', 0.003383114452298113, 0, 0, False),
#  ('15net_pop_child', 0.0024253967489093918, 0, 0, False),
#  ('15net_pop_old', 0.052524836817233057, 0, 0, False),
#  ('15net_pop_poor', 0.0047446417311244387, 0, 0, False),
#  ('15net_pop_rich', 0.0011285929508332453, 0, 0, False),
#  ('15net_population', 0.053284931718153052, 0, 0, False),
#  ('15net_university', 0.01111817402612169, 0, 0, False),
#  ('30net_bachelors', 0.001146499088693286, 1, 0.00028799923705843695, False),
#  ('30net_business', 0.0013093347587067883, 0, 0, False),
#  ('30net_emp_full_time',
#   0.00032282329453349077,
#   4,
#   2.8711893337580935e-05,
#   False),
#  ('30net_emp_pay', 0.031567931375237133, 0, 0, False),
#  ('30net_employed', 0.00016168690463817499, 3, 0.00010440695566416357, False),
#  ('30net_employment', 0.00043769392919809099, 0, 0, False),
#  ('30net_entertainment', 0.00014939426694979388, 0, 0, False),
#  ('30net_family', 0.0011910796363626534, 1, 0.00013163538459463393, False),
#  ('30net_finance', 0.00089174340891086498, 0, 0, False),
#  ('30net_hospitality', 0.00021621750737449696, 0, 0, False),
#  ('30net_house_w_child', 0.00039215395634142295, 0, 0, False),
#  ('30net_household', 0.000146978083384718, 4, 2.8711893337580935e-05, False),
#  ('30net_hunits_attached', 0.00043153738412014721, 0, 0, False),
#  ('30net_hunits_detached', 0.010460855907639191, 0, 0, False),
#  ('30net_hunits_large', 6.5145677802313937e-05, 0, 0, False),
#  ('30net_hunits_medium', 0.00018780664879228069, 0, 0, False),
#  ('30net_hunits_new', 0.00017763577624905531, 0, 0, False),
#  ('30net_hunits_old', 0.0033973418373910423, 0, 0, False),
#  ('30net_hunits_owner', 0.008778289183138584, 0, 0, False),
#  ('30net_hunits_renter', 0.0048718197388536878, 0, 0, False),
#  ('30net_hunits_vacant', 0.0018670050666168042, 0, 0, False),
#  ('30net_medical', 0.015868314943095881, 0, 0, False),
#  ('30net_pop_child', 0.0057770136067126854, 0, 0, False),
#  ('30net_pop_old', 0.001560469708313918, 0, 0, False),
#  ('30net_pop_poor', 0.00046724060285569517, 0, 0, False),
#  ('30net_university', 0.0045802439330075917, 0, 0, False),
#  ('60net_bachelors', 0.00011314609507415014, 2, 1.976004044229574e-05, False),
#  ('60net_business', 0.00089439866630514346, 0, 0, False),
#  ('60net_emp_full_time',
#   0.0014149988465700057,
#   4,
#   3.2045386832697929e-05,
#   False),
#  ('60net_emp_pay', 0.003536531881178332, 0, 0, False),
#  ('60net_employed', 0.00011367756470675877, 5, 6.6787926549970289e-05, False),
#  ('60net_employment', 7.8436441532741432e-05, 0, 0, False),
#  ('60net_entertainment', 0.00017809191660178651, 0, 0, False),
#  ('60net_family', 0.00034349593568641152, 2, 0.00021430200588977685, False),
#  ('60net_finance', 0.00018085217257815658, 0, 0, False),
#  ('60net_hospitality', 0.00096650978758218886, 0, 0, False),
#  ('60net_house_w_child', 0.00024404442125936662, 0, 0, False),
#  ('60net_household', 6.6787926549970289e-05, 4, 3.2045386832697929e-05, False),
#  ('60net_hunits_attached',
#   0.00042657580696151291,
#   2,
#   0.00012111420752753187,
#   False),
#  ('60net_hunits_detached', 0.0024087267397406272, 0, 0, False),
#  ('60net_hunits_large', 0.00011767587631821407, 0, 0, False),
#  ('60net_hunits_medium',
#   0.00012111420752753187,
#   4,
#   1.976004044229574e-05,
#   False),
#  ('60net_hunits_new', 0.0017263887482985613, 0, 0, False),
#  ('60net_hunits_old',
#   0.00042818044255859557,
#   2,
#   0.00012111420752753187,
#   False),
#  ('60net_hunits_owner', 0.0027655695673128094, 0, 0, False),
#  ('60net_hunits_renter',
#   0.00021430200588977685,
#   5,
#   0.00011367756470675877,
#   False),
#  ('60net_hunits_vacant', 0.00048659800270415025, 0, 0, False),
#  ('60net_labor_force',
#   0.00019073149892767516,
#   6,
#   6.6787926549970289e-05,
#   False),
#  ('60net_medical', 0.00092566889854898428, 0, 0, False),
#  ('60net_pop_child', 0.00015987750837927244, 0, 0, False),
#  ('60net_pop_old', 0.00086659438326695674, 3, 0.00011367756470675877, False),
#  ('60net_pop_poor', 0.0024046836898392325, 0, 0, False),
#  ('60net_population',
#   0.00060345813097074648,
#   3,
#   0.00019073149892767516,
#   False),
#  ('60net_university', 0.00063735664841793344, 0, 0, False),
#  ('near_bachelors', 0.03122889171368497, 0, 0, False),
#  ('near_business', 0.013178628804163605, 0, 0, False),
#  ('near_emp_full_time', 0.0083005361405815194, 0, 0, False),
#  ('near_emp_pay', 0.001015162582219177, 0, 0, False),
#  ('near_employment', 0.008253533078889444, 0, 0, False),
#  ('near_entertainment', 0.0027705454649484024, 0, 0, False),
#  ('near_family', 0.00022722412303390814, 0, 0, False),
#  ('near_finance', 0.010535977197679519, 0, 0, False),
#  ('near_hospitality', 0.0038774387619928919, 0, 0, False),
#  ('near_house_w_child', 0.0013573684538177254, 0, 0, False),
#  ('near_household', 0.016070561388668712, 1, 0.0024649207744563608, False),
#  ('near_hunits_attached', 0.0018272876388375748, 0, 0, False),
#  ('near_hunits_detached', 0.0017094927862588104, 0, 0, False),
#  ('near_hunits_large', 0.0019313869616773781, 0, 0, False),
#  ('near_hunits_medium', 0.0023595522460431273, 0, 0, False),
#  ('near_hunits_new', 0.0036377375800584503, 0, 0, False),
#  ('near_hunits_old', 0.0030060300299544268, 0, 0, False),
#  ('near_hunits_owner', 0.030547234715202303, 0, 0, False),
#  ('near_hunits_renter', 0.0003193530744149663, 0, 0, False),
#  ('near_hunits_vacant', 0.0042384113083886611, 0, 0, False),
#  ('near_labor_force', 0.0041732792569205814, 1, 0.0012475036599142854, False),
#  ('near_medical', 0.0013423437187447111, 0, 0, False),
#  ('near_pop_child', 1.6596108052485923e-05, 0, 0, False),
#  ('near_pop_old', 0.013756715524478472, 0, 0, False),
#  ('near_pop_poor', 0.00079345090174906627, 0, 0, False),
#  ('near_pop_rich', 0.00070598634684192391, 0, 0, False),
#  ('near_population', 0.00070592049290770756, 0, 0, False),
#  ('near_university', 0.0063465303585100146, 0, 0, False),
#  ('parking', 0.0011041799886161521, 0, 0, False),
#  ('walk_bachelors', 0.0043705758342814979, 0, 0, False),
#  ('walk_business', 0.0018488067305735395, 0, 0, False),
#  ('walk_emp_full_time', 0.00093529298468401911, 0, 0, False),
#  ('walk_emp_pay', 0.0021604803566677129, 0, 0, False),
#  ('walk_employed', 0.0040884198390042656, 1, 0.0039010567639515851, False),
#  ('walk_employment', 9.7076825150069316e-05, 0, 0, False),
#  ('walk_entertainment', 0.002797803105492702, 0, 0, False),
#  ('walk_family', 0.0021268351235394166, 0, 0, False),
#  ('walk_finance', 0.0012349403638188239, 0, 0, False),
#  ('walk_hospitality', 0.00066095436932428323, 0, 0, False),
#  ('walk_house_w_child', 0.0048393403587575585, 0, 0, False),
#  ('walk_hunits', 0.0097343576285956294, 1, 0.0016135731308468502, False),
#  ('walk_hunits_attached', 0.018339927269522348, 0, 0, False),
#  ('walk_hunits_detached', 0.024450781299703274, 0, 0, False),
#  ('walk_hunits_large', 0.0029106169384908089, 0, 0, False),
#  ('walk_hunits_medium', 0.006345190089285779, 0, 0, False),
#  ('walk_hunits_new', 0.0064239839719474143, 0, 0, False),
#  ('walk_hunits_old', 0.0019529938883609548, 0, 0, False),
#  ('walk_hunits_owner', 0.0017858313198508269, 0, 0, False),
#  ('walk_hunits_renter', 0.0016769582752090874, 0, 0, False),
#  ('walk_hunits_vacant', 0.00021158187903645462, 0, 0, False),
#  ('walk_medical', 0.0027648407627011559, 0, 0, False),
#  ('walk_pop_child', 0.015903173117349872, 0, 0, False),
#  ('walk_pop_old', 0.0045866010278427984, 0, 0, False),
#  ('walk_pop_poor', 0.0087616470688970695, 0, 0, False),
#  ('walk_pop_rich', 0.00081787717341329376, 0, 0, False),
#  ('walk_population', 0.0020107125669561704, 0, 0, False),
#  ('walk_university', 0.00047850640920298884, 0, 0, False)]

# %%
for k, v in sorted([(k, v) for k, v in featScore.items()], key=lambda x: x[1], reverse=True):
    print(k, v)
# Out:
# 15net_family 0.110946150931
# 15net_house_w_child 0.105154991853
# 15net_business 0.0575889291829
# 15net_population 0.0532849317182
# 15net_pop_old 0.0525248368172
# 15net_emp_pay 0.0412963177918
# 15net_hunits_attached 0.0412799727111
# 30net_emp_pay 0.0315679313752
# near_bachelors 0.0312288917137
# near_hunits_owner 0.0305472347152
# walk_hunits_detached 0.0244507812997
# 15net_bachelors 0.0186874127139
# walk_hunits_attached 0.0183399272695
# 15net_hunits_detached 0.0169487263904
# near_household 0.0160705613887
# walk_pop_child 0.0159031731173
# 30net_medical 0.0158683149431
# near_pop_old 0.0137567155245
# near_business 0.0131786288042
# 15net_employment 0.0119859222617
# 15net_university 0.0111181740261
# near_finance 0.0105359771977
# 30net_hunits_detached 0.0104608559076
# walk_hunits 0.0097343576286
# 30net_hunits_owner 0.00877828918314
# walk_pop_poor 0.0087616470689
# near_emp_full_time 0.00830053614058
# near_employment 0.00825353307889
# 15net_hospitality 0.00740298902437
# walk_hunits_new 0.00642398397195
# near_university 0.00634653035851
# walk_hunits_medium 0.00634519008929
# 30net_pop_child 0.00577701360671
# 30net_hunits_renter 0.00487181973885
# walk_house_w_child 0.00483934035876
# 15net_pop_poor 0.00474464173112
# walk_pop_old 0.00458660102784
# 30net_university 0.00458024393301
# 15net_hunits_medium 0.00444072586446
# walk_bachelors 0.00437057583428
# near_hunits_vacant 0.00423841130839
# near_labor_force 0.00417327925692
# walk_employed 0.004088419839
# walk_labor_force 0.00390105676395
# near_hospitality 0.00387743876199
# near_hunits_new 0.00363773758006
# 60net_emp_pay 0.00353653188118
# 30net_hunits_old 0.00339734183739
# 15net_emp_full_time 0.00339443071126
# 15net_medical 0.0033831144523
# near_hunits_old 0.00300603002995
# walk_hunits_large 0.00291061693849
# walk_entertainment 0.00279780310549
# near_entertainment 0.00277054546495
# 60net_hunits_owner 0.00276556956731
# walk_medical 0.0027648407627
# 15net_hunits_large 0.00262360243527
# near_hunits 0.00246492077446
# 15net_pop_child 0.00242539674891
# 60net_hunits_detached 0.00240872673974
# 60net_pop_poor 0.00240468368984
# near_hunits_medium 0.00235955224604
# walk_emp_pay 0.00216048035667
# walk_family 0.00212683512354
# walk_population 0.00201071256696
# 15net_household 0.00196899804999
# walk_hunits_old 0.00195299388836
# 15net_hunits_renter 0.00193370868553
# near_hunits_large 0.00193138696168
# 30net_hunits_vacant 0.00186700506662
# walk_business 0.00184880673057
# near_hunits_attached 0.00182728763884
# walk_hunits_owner 0.00178583131985
# 60net_hunits_new 0.0017263887483
# near_hunits_detached 0.00170949278626
# 15net_hunits_vacant 0.00168673754247
# walk_hunits_renter 0.00167695827521
# walk_household 0.00161357313085
# 30net_pop_old 0.00156046970831
# 60net_emp_full_time 0.00141499884657
# 15net_hunits_new 0.00139255181922
# near_house_w_child 0.00135736845382
# near_medical 0.00134234371874
# 30net_business 0.00130933475871
# near_employed 0.00124750365991
# walk_finance 0.00123494036382
# 30net_family 0.00119107963636
# 30net_bachelors 0.00114649908869
# 15net_pop_rich 0.00112859295083
# parking 0.00110417998862
# 15net_employed 0.001050805939
# near_emp_pay 0.00101516258222
# 60net_hospitality 0.000966509787582
# walk_emp_full_time 0.000935292984684
# 60net_medical 0.000925668898549
# 60net_business 0.000894398666305
# 30net_finance 0.000891743408911
# 60net_pop_old 0.000866594383267
# walk_pop_rich 0.000817877173413
# near_pop_poor 0.000793450901749
# 15net_hunits_owner 0.000755999874643
# 15net_entertainment 0.000720466361601
# near_pop_rich 0.000705986346842
# near_population 0.000705920492908
# 15net_finance 0.000692416042793
# walk_hospitality 0.000660954369324
# 60net_university 0.000637356648418
# 60net_population 0.000603458130971
# 60net_hunits_vacant 0.000486598002704
# walk_university 0.000478506409203
# 30net_pop_poor 0.000467240602856
# 30net_employment 0.000437693929198
# 30net_hunits_attached 0.00043153738412
# 60net_hunits_old 0.000428180442559
# 60net_hunits_attached 0.000426575806962
# 15net_labor_force 0.000411931177387
# 30net_house_w_child 0.000392153956341
# 60net_family 0.000343495935686
# 30net_emp_full_time 0.000322823294533
# near_hunits_renter 0.000319353074415
# 30net_pop_rich 0.000287999237058
# 15net_hunits 0.000263360828207
# 60net_house_w_child 0.000244044421259
# 15net_hunits_old 0.000239356774915
# near_family 0.000227224123034
# 30net_hospitality 0.000216217507374
# 60net_hunits_renter 0.00021430200589
# walk_hunits_vacant 0.000211581879036
# 60net_labor_force 0.000190731498928
# 30net_hunits_medium 0.000187806648792
# 60net_finance 0.000180852172578
# 60net_entertainment 0.000178091916602
# 30net_hunits_new 0.000177635776249
# 30net_employed 0.000161686904638
# 60net_pop_child 0.000159877508379
# 30net_entertainment 0.00014939426695
# 30net_household 0.000146978083385
# 30net_population 0.000131635384595
# 60net_hunits_medium 0.000121114207528
# 60net_hunits_large 0.000117675876318
# 60net_employed 0.000113677564707
# 60net_bachelors 0.000113146095074
# 30net_labor_force 0.000104406955664
# walk_employment 9.70768251501e-05
# 60net_employment 7.84364415327e-05
# 60net_household 6.678792655e-05
# 30net_hunits_large 6.51456778023e-05
# 60net_hunits 3.20453868327e-05
# 30net_hunits 2.87118933376e-05
# 60net_pop_rich 1.97600404423e-05
# near_pop_child 1.65961080525e-05
