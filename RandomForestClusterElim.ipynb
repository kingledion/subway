# %%
from regression import citylist, loadData
import itertools, numpy as np, scipy.stats as stats
from sklearn.cluster import affinity_propagation, spectral_clustering
from sklearn.ensemble import RandomForestRegressor

# %%
# load data
df = loadData(citylist)
cols = list(df.columns.difference(['lat', 'lon', 'name', 'riders']))

# %%
# Regression for each possible combo of features
combos = [(a, b) for a, b in itertools.combinations(cols, 2) if a != b]
data = []
for a, b in combos:
    y = df[a]
    x = df[b]
    slope, intercept, rval, pval, stderr = stats.linregress(x, y)
    rs = rval**2
    data.append((a, b, rs))

# %%
# Build affinity matrix; default affinity is 1 (for value to itself)
adj = np.ones([len(cols), len(cols)])
for istr, jstr, score in data:
    i = cols.index(istr)
    j = cols.index(jstr)
    adj[i][j] = score
    adj[j][i] = score

# %%
df2 = df[clusters[9]]

# %%
scores = {c: [] for c in clusters[9]}
for _ in range(100):
    rf = RandomForestRegressor(max_features='log2')
    rf.fit(df2, df['riders'])
    for name, s in zip(clusters[9], rf.feature_importances_):
        scores[name].append(s)

out = [(name, np.mean(s)) for name, s in scores.items()]
for name, score in sorted(out, key=lambda x: x[1]):
    print(name, score)
# Out:
# near_house_w_child 0.179022183915
# near_family 0.185022164597
# near_pop_poor 0.18637702309
# near_population 0.215517532877
# near_pop_child 0.234061095522

# %%
data = [(x, y) for x, y in enumerate(adj[cols.index('near_pop_child')])]

# %%
cols[118]
# Out:
# 'near_population'

# %%
sorted(data, key=lambda x: x[1], reverse = True)
# Out:
# [(114, 1.0),
#  (100, 0.94472953065075882),
#  (116, 0.86290240901723181),
#  (97, 0.82568380589605916),
#  (118, 0.75125447725030947),
#  (145, 0.64041147589977476),
#  (112, 0.53795030373495589),
#  (115, 0.51305995546681649),
#  (94, 0.48437670466484439),
#  (104, 0.43602156332772668),
#  (92, 0.42398754211854101),
#  (131, 0.41624171705991037),
#  (135, 0.40134654326055358),
#  (101, 0.39264663866241728),
#  (147, 0.39081142873171743),
#  (102, 0.37891150059570022),
#  (103, 0.37655430928535982),
#  (110, 0.36445216327291591),
#  (108, 0.29384795044250844),
#  (86, 0.2744382110735587),
#  (24, 0.27027961904166337),
#  (74, 0.26016109571719653),
#  (14, 0.23545958587790006),
#  (106, 0.23534856190870224),
#  (84, 0.22839072105195246),
#  (26, 0.21764518480731476),
#  (109, 0.20749237117196243),
#  (70, 0.1863329182565123),
#  (10, 0.18123566661230181),
#  (128, 0.1533703034673346),
#  (67, 0.14901569326538941),
#  (111, 0.14720651133839949),
#  (88, 0.14171511464658582),
#  (80, 0.13221171426024858),
#  (127, 0.1266322736817895),
#  (82, 0.11456448986366144),
#  (85, 0.10758935919006087),
#  (64, 0.10612254123931712),
#  (75, 0.10321077766813416),
#  (134, 0.099540163744594651),
#  (66, 0.09774260534225318),
#  (130, 0.095217946613560714),
#  (62, 0.094947590375109497),
#  (56, 0.093082443216490188),
#  (126, 0.090712665076574522),
#  (71, 0.089608089997595675),
#  (124, 0.086212582858358922),
#  (72, 0.084313772964889719),
#  (7, 0.083413875212336369),
#  (54, 0.079241606199881603),
#  (44, 0.072746258003690792),
#  (122, 0.068111364754006268),
#  (150, 0.066092255253558579),
#  (23, 0.064495325531436346),
#  (129, 0.064301396276747663),
#  (144, 0.0617520391136092),
#  (29, 0.059452092829446301),
#  (121, 0.059445592005869061),
#  (148, 0.058393489656434039),
#  (28, 0.051038780925381555),
#  (40, 0.050132916722530521),
#  (138, 0.049709091636864204),
#  (81, 0.048219969144201534),
#  (9, 0.044598032216895178),
#  (3, 0.044240984848169837),
#  (53, 0.04395139885443549),
#  (105, 0.042921688070370771),
#  (1, 0.042896031422764956),
#  (149, 0.039447678709648028),
#  (78, 0.036807737503090306),
#  (8, 0.036698478299213105),
#  (77, 0.036576298928075707),
#  (5, 0.035583469039003411),
#  (91, 0.035221020437508958),
#  (73, 0.035028501205561689),
#  (79, 0.03395155530947469),
#  (93, 0.032515059204436349),
#  (136, 0.031453284526346111),
#  (13, 0.029655633096005468),
#  (37, 0.029263589147549673),
#  (59, 0.029204488368071355),
#  (96, 0.026436498025804989),
#  (99, 0.02631241267502029),
#  (25, 0.025563691415294729),
#  (76, 0.024095812498843645),
#  (6, 0.023735704125978713),
#  (95, 0.02329069804314347),
#  (98, 0.022865075547999009),
#  (90, 0.021419843706901535),
#  (58, 0.021312029347967654),
#  (22, 0.020960450738545945),
#  (117, 0.019744191234165844),
#  (17, 0.017775755979640505),
#  (60, 0.01518531095068378),
#  (4, 0.01499934381222953),
#  (65, 0.01419160724704795),
#  (143, 0.013469861614194001),
#  (27, 0.012138071040159609),
#  (0, 0.01213538616230464),
#  (52, 0.01204412453012357),
#  (20, 0.011673927407480675),
#  (50, 0.011381209559095133),
#  (87, 0.011212286076023729),
#  (55, 0.010944620318954663),
#  (89, 0.010685966121617931),
#  (146, 0.01026960709125507),
#  (119, 0.0099684510253392946),
#  (34, 0.0096884705517374589),
#  (69, 0.0096576634828266523),
#  (2, 0.008820025214293108),
#  (120, 0.0082451749956060968),
#  (18, 0.0076215982487776715),
#  (32, 0.0071939985481445532),
#  (83, 0.0070951478314061527),
#  (45, 0.0069402372414241152),
#  (125, 0.0062192210420619082),
#  (142, 0.005826353242637596),
#  (11, 0.0057331035059316514),
#  (140, 0.005290117443206511),
#  (41, 0.0050203753224476741),
#  (12, 0.0041652776520782466),
#  (42, 0.00394194925584545),
#  (30, 0.0033299297865956841),
#  (57, 0.0030460210188802952),
#  (123, 0.0030046814919687673),
#  (137, 0.0028680087654764145),
#  (61, 0.0028245641462841353),
#  (139, 0.0027263663759937453),
#  (113, 0.0025690727665833709),
#  (46, 0.0023143473674426584),
#  (15, 0.0020029248503847844),
#  (16, 0.0017184518220955676),
#  (36, 0.0015646478169787008),
#  (47, 0.00097779396304542078),
#  (141, 0.0007901437791921317),
#  (31, 0.0006778358026120067),
#  (21, 0.00052068799331215826),
#  (39, 0.00047095762714303643),
#  (107, 0.00046985239295158174),
#  (68, 0.00033460214445563477),
#  (38, 0.00030247417777518732),
#  (33, 0.00025385717325632424),
#  (133, 0.00022395153122424348),
#  (35, 0.00018308073066046013),
#  (48, 0.00010659461939520094),
#  (63, 6.7831900293828984e-05),
#  (19, 5.3680886942064099e-05),
#  (132, 3.3423787987334259e-05),
#  (49, 2.4341356000081817e-05),
#  (43, 2.0492985357050199e-05),
#  (51, 9.3209983872983889e-06)]

# %%
centers, labels = affinity_propagation(adj)
clusters = {}
for name, c in zip(cols, labels):
    if c in clusters:
        clusters[c].append(name)
    else:
        clusters[c] = [name]
for c in clusters:
    print(c)
    print(clusters[c])
# Out:
# 0
# ['15net_business', '15net_emp_pay', '15net_employment', '15net_entertainment', '15net_finance', '15net_hospitality', '15net_hunits_new']
# 1
# ['15net_bachelors', '15net_emp_full_time', '15net_employed', '15net_family', '15net_household', '15net_hunits', '15net_hunits_attached', '15net_hunits_large', '15net_hunits_medium', '15net_hunits_old', '15net_hunits_owner', '15net_hunits_renter', '15net_hunits_vacant', '15net_labor_force', '15net_pop_old', '15net_pop_rich', '15net_population']
# 2
# ['15net_house_w_child', '15net_hunits_detached', '15net_pop_child', '15net_pop_poor', '30net_hunits_detached']
# 3
# ['30net_business', '30net_emp_pay', '30net_employment', '30net_entertainment', '30net_finance', '30net_hospitality']
# 4
# ['30net_bachelors', '30net_emp_full_time', '30net_employed', '30net_family', '30net_house_w_child', '30net_household', '30net_hunits', '30net_hunits_attached', '30net_hunits_large', '30net_hunits_medium', '30net_hunits_new', '30net_hunits_old', '30net_hunits_owner', '30net_hunits_renter', '30net_hunits_vacant', '30net_labor_force', '30net_pop_child', '30net_pop_old', '30net_pop_poor', '30net_pop_rich', '30net_population']
# 5
# ['15net_medical', '15net_university', '30net_medical', '30net_university', '60net_medical', '60net_university']
# 6
# ['60net_bachelors', '60net_business', '60net_emp_pay', '60net_employment', '60net_finance', '60net_hospitality', '60net_hunits_attached', '60net_hunits_medium', '60net_hunits_new', '60net_hunits_old', '60net_hunits_owner', '60net_hunits_vacant', '60net_pop_rich']
# 7
# ['60net_emp_full_time', '60net_employed', '60net_entertainment', '60net_family', '60net_house_w_child', '60net_household', '60net_hunits', '60net_hunits_detached', '60net_hunits_large', '60net_hunits_renter', '60net_labor_force', '60net_pop_child', '60net_pop_old', '60net_pop_poor', '60net_population']
# 8
# ['near_business', 'near_emp_pay', 'near_employment', 'near_entertainment', 'near_finance', 'near_hospitality']
# 9
# ['near_family', 'near_house_w_child', 'near_pop_child', 'near_pop_poor', 'near_population']
# 10
# ['near_emp_full_time', 'near_employed', 'near_household', 'near_hunits', 'near_hunits_large', 'near_hunits_renter', 'near_hunits_vacant', 'near_labor_force', 'near_pop_old']
# 11
# ['near_hunits_detached', 'walk_hunits_detached']
# 12
# ['near_hunits_attached', 'near_hunits_medium', 'near_hunits_old', 'walk_hunits_attached']
# 13
# ['near_medical', 'walk_medical']
# 14
# ['near_bachelors', 'near_hunits_new', 'near_hunits_owner', 'near_pop_rich']
# 15
# ['parking']
# 16
# ['walk_business', 'walk_emp_pay', 'walk_employment', 'walk_entertainment', 'walk_finance', 'walk_hospitality', 'walk_hunits_new']
# 17
# ['walk_bachelors', 'walk_emp_full_time', 'walk_employed', 'walk_family', 'walk_household', 'walk_hunits', 'walk_hunits_large', 'walk_hunits_medium', 'walk_hunits_old', 'walk_hunits_owner', 'walk_hunits_renter', 'walk_hunits_vacant', 'walk_labor_force', 'walk_pop_old', 'walk_pop_rich', 'walk_population']
# 18
# ['walk_house_w_child', 'walk_pop_child', 'walk_pop_poor']
# 19
# ['near_university', 'walk_university']

# %%
def remove_cols(to_remove, rcols, radj):
    i_to_remove = [rcols.index(name) for name in to_remove]
    radj = np.delete(radj, i_to_remove, axis = 0)
    radj = np.delete(radj, i_to_remove, axis = 1)
    rcols = [name for i, name in enumerate(rcols) if i not in i_to_remove]
    return rcols, radj

# %%
rf = RandomForestRegressor(max_features='log2')
rf.fit(df[cols], df['riders'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='log2', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
data = sorted([(name, score) for name, score in zip(cols, rf.feature_importances_)], key=lambda x:x[1], reverse=True)
for d in data:
    print(d)
# Out:
# ('30net_hunits_detached', 0.093772865259808047)
# ('15net_population', 0.063509592785467112)
# ('15net_pop_poor', 0.045356127577798652)
# ('near_employment', 0.035898281956300612)
# ('15net_entertainment', 0.033363939465154376)
# ('15net_hunits_attached', 0.029527585878582129)
# ('walk_entertainment', 0.029358971266068356)
# ('walk_hunits_vacant', 0.02701120881341354)
# ('30net_hunits_vacant', 0.024946845829902406)
# ('15net_pop_old', 0.024126224430420552)
# ('walk_employment', 0.024035931528499557)
# ('15net_hunits_renter', 0.022747902126581072)
# ('15net_emp_pay', 0.022181532305590994)
# ('30net_hunits_new', 0.021284251156469647)
# ('60net_employed', 0.015350575253033415)
# ('15net_hunits_owner', 0.015300120836224488)
# ('near_pop_rich', 0.015271730959104415)
# ('near_household', 0.013574203407501775)
# ('near_pop_old', 0.013511066890044878)
# ('near_business', 0.012973389561307109)
# ('near_hospitality', 0.01265711142754947)
# ('15net_employment', 0.012600174167173017)
# ('30net_pop_poor', 0.012491732446172975)
# ('near_hunits_medium', 0.01173212036155667)
# ('walk_emp_pay', 0.011546806432787583)
# ('15net_bachelors', 0.011122239224752336)
# ('walk_family', 0.01103870742997699)
# ('near_hunits_owner', 0.010560537955896829)
# ('30net_emp_pay', 0.0099685550941442831)
# ('walk_business', 0.0097977726169698257)
# ('30net_emp_full_time', 0.0097468914693796503)
# ('near_pop_child', 0.0081466523268098993)
# ('15net_hunits_medium', 0.006958275490043386)
# ('near_employed', 0.0069099965959232195)
# ('60net_hospitality', 0.0068429895872089835)
# ('30net_pop_rich', 0.0067014658540153942)
# ('near_hunits_renter', 0.0066337147384064737)
# ('15net_hunits', 0.0066126113471597749)
# ('near_medical', 0.0065580666611519418)
# ('near_hunits', 0.0062804948408598585)
# ('30net_hunits_owner', 0.0062529349032079658)
# ('30net_family', 0.0061341585319421967)
# ('walk_hunits', 0.0061296055315304817)
# ('60net_hunits_old', 0.0060963578182150081)
# ('walk_household', 0.0059261044234226222)
# ('near_hunits_vacant', 0.0058720261842039254)
# ('15net_business', 0.0055262232100392614)
# ('near_emp_pay', 0.005304797144911803)
# ('30net_hunits_attached', 0.0052509687500189401)
# ('30net_medical', 0.0052221372010762424)
# ('30net_employment', 0.0049808853967780228)
# ('near_hunits_detached', 0.0049551274127253584)
# ('15net_household', 0.0049220321242519714)
# ('30net_university', 0.0049141666451297406)
# ('near_university', 0.0047670427568488874)
# ('walk_pop_child', 0.0046955399928522989)
# ('near_bachelors', 0.0046653760098167756)
# ('15net_hospitality', 0.0046079210069955006)
# ('near_house_w_child', 0.0045924960680269458)
# ('15net_pop_child', 0.0045184660423571738)
# ('walk_hunits_new', 0.0043653744804357814)
# ('15net_hunits_old', 0.004128562467004211)
# ('60net_pop_child', 0.004091709623594595)
# ('15net_labor_force', 0.0037844491328318255)
# ('60net_emp_pay', 0.0036063189433330326)
# ('near_entertainment', 0.003551954785704687)
# ('walk_hospitality', 0.0034971045600380181)
# ('15net_emp_full_time', 0.0032195740258171368)
# ('15net_pop_rich', 0.0030542851333824226)
# ('15net_medical', 0.0027684717674741279)
# ('walk_population', 0.0027512174201087774)
# ('walk_hunits_medium', 0.0027231481726334031)
# ('walk_hunits_old', 0.002703747979491568)
# ('30net_hunits_large', 0.0026714317949207596)
# ('60net_finance', 0.0026601554206620278)
# ('near_pop_poor', 0.0026354779269844412)
# ('near_labor_force', 0.0025163787146433962)
# ('30net_business', 0.0025031276915324589)
# ('30net_employed', 0.0023784107131882824)
# ('walk_hunits_owner', 0.0023585219322819488)
# ('60net_pop_poor', 0.0022675824005595965)
# ('60net_university', 0.0022317149114533933)
# ('near_finance', 0.0021429550244625611)
# ('30net_finance', 0.0021289125241621696)
# ('walk_hunits_detached', 0.0020660432656685063)
# ('15net_family', 0.0020629113833314102)
# ('near_hunits_old', 0.0019830031387098853)
# ('walk_pop_rich', 0.0019595110145891903)
# ('30net_labor_force', 0.0018973222196242701)
# ('15net_university', 0.0018558919389133396)
# ('15net_house_w_child', 0.0018245994260104707)
# ('walk_pop_old', 0.0017909660434308589)
# ('30net_entertainment', 0.0017219818683431279)
# ('near_hunits_attached', 0.0017075712858638456)
# ('near_population', 0.0016273265827834392)
# ('30net_hunits_medium', 0.0014542591359524174)
# ('30net_hunits_old', 0.0013663277828050119)
# ('walk_university', 0.0013629640344014946)
# ('15net_hunits_vacant', 0.0013339578806377855)
# ('60net_family', 0.0013295846504139789)
# ('15net_hunits_new', 0.001303983797493182)
# ('60net_bachelors', 0.0012093473816660871)
# ('walk_labor_force', 0.0011452781166585797)
# ('15net_finance', 0.0011417856325568912)
# ('30net_hunits_renter', 0.0011233915613197407)
# ('walk_hunits_renter', 0.0010970959717833306)
# ('60net_medical', 0.0010753768272873377)
# ('walk_bachelors', 0.0010733409269756081)
# ('walk_hunits_large', 0.0010425492446180557)
# ('30net_hunits', 0.0010216393661045512)
# ('walk_finance', 0.0009952021222306485)
# ('near_hunits_large', 0.00091718242435110471)
# ('60net_hunits_large', 0.00091493582173710292)
# ('30net_pop_child', 0.00080420931456939263)
# ('60net_hunits_attached', 0.00073128344280152754)
# ('near_hunits_new', 0.00070041074948288249)
# ('walk_hunits_attached', 0.00069940247109356055)
# ('30net_bachelors', 0.00067618243272461623)
# ('15net_hunits_detached', 0.00064249493964483207)
# ('60net_pop_rich', 0.00061154551393579183)
# ('30net_population', 0.00059285574362888524)
# ('60net_hunits_medium', 0.00057958593856992054)
# ('walk_medical', 0.00053640396096443538)
# ('walk_pop_poor', 0.00048902210082540129)
# ('60net_hunits_vacant', 0.0004800846657672788)
# ('30net_pop_old', 0.00045560109926903909)
# ('30net_household', 0.00045463719179416164)
# ('60net_hunits_renter', 0.00044337415134790254)
# ('60net_entertainment', 0.0004432059643841279)
# ('60net_emp_full_time', 0.0004217446888273999)
# ('walk_house_w_child', 0.00041540968205873061)
# ('15net_employed', 0.00041237997468855864)
# ('60net_hunits', 0.00036092847032670114)
# ('30net_hospitality', 0.00035803530193673309)
# ('15net_hunits_large', 0.0003379058726994542)
# ('walk_emp_full_time', 0.00026932275150098829)
# ('near_family', 0.00025981641536955218)
# ('60net_business', 0.00025739559116928464)
# ('60net_house_w_child', 0.00024956308054850088)
# ('near_emp_full_time', 0.0002432574526544638)
# ('60net_hunits_new', 0.00022452978284690682)
# ('60net_hunits_owner', 0.00018445334155231473)
# ('walk_employed', 0.00018293448518003286)
# ('60net_hunits_detached', 0.00017724629392392642)
# ('60net_employment', 0.00016665997684658414)
# ('60net_population', 0.00016150241215481548)
# ('60net_household', 0.000139325091411542)
# ('60net_labor_force', 0.00011875474819140984)
# ('60net_pop_old', 0.00011409827904036027)
# ('30net_house_w_child', 7.3003122730631477e-05)
# ('parking', 4.1884601012678184e-05)

# %%
def choose_best():
    rcols = [x for x in cols]
    radj = np.array(adj)
    keep = []
    while len(rcols) > 1:
        keep, rcols, radj = one_iter(keep, rcols, radj)
    
    keep.extend(rcols)
    return keep

# %%
def one_iter(keep, rcols, radj):
    rf = RandomForestRegressor()
    rf.fit(df[rcols], df['riders'])
    featScore = {name: score for score, name in zip(rf.feature_importances_, rcols)}

    if len(rcols) == 2:
        if featScore[rcols[0]] > featScore[rcols[1]]:
            del rcols[1]
            return keep, rcols, radj
        else:
            del rcols[0]
            return keep, rcols, radj


    centers, labels = affinity_propagation(radj)
    clusters = {}
    #print(len(rcols), len(labels))
    try:
        for name, c in zip(rcols, labels):
            if c in clusters:
                clusters[c].append(name)
            else:
                clusters[c] = [name]
    except TypeError as e:
        print(rcols, labels)
        raise e
    drop_clusters = []
    for c, names in clusters.items():
        if len(names) == 1:
            #print("Single cluster, keeping: ", names)
            drop_clusters.append(c)
            keep.extend(names)
            rcols, radj = remove_cols(names, rcols, radj)
    for to_drop in drop_clusters:
        del clusters[to_drop]

    to_remove = []
    for c, names in clusters.items():
        #print("Cluster") # Remove
        #for n in names:
        #    print(n, featScore[n])
        name, minVal = min(zip(names, [featScore[n] for n in names]), key=lambda x: x[1])
        #print("Lowest in cluster, dropping: ", name, minVal)
        to_remove.append(name)
    rcols, radj = remove_cols(to_remove, rcols, radj)
    
    return keep, rcols, radj

# %%
choose_best()
# Out:
# Single cluster, keeping:  ['parking']
# Cluster
# 15net_business 0.0166224719
# 15net_emp_pay 0.000106013773345
# 15net_employment 0.00131183198163
# 15net_entertainment 0.00221766924499
# 15net_finance 0.0057302579702
# 15net_hospitality 0.00216665341327
# 15net_hunits_new 0.00034177438936
# Lowest in cluster, dropping:  15net_emp_pay 0.000106013773345
# Cluster
# 15net_bachelors 0.000275723378745
# 15net_emp_full_time 0.00369076443603
# 15net_employed 0.000342906930573
# 15net_family 0.0537819600326
# 15net_household 0.000911320426072
# 15net_hunits 0.000818656682765
# 15net_hunits_attached 0.00114731206639
# 15net_hunits_large 0.00286425183029
# 15net_hunits_medium 0.0123275563621
# 15net_hunits_old 0.0013300520094
# 15net_hunits_owner 0.010411133919
# 15net_hunits_renter 0.00048220510755
# 15net_hunits_vacant 0.00107922556538
# 15net_labor_force 0.000615102727736
# 15net_pop_old 0.0380590575648
# 15net_pop_rich 0.00020890283751
# 15net_population 0.16833039848
# Lowest in cluster, dropping:  15net_pop_rich 0.00020890283751
# Cluster
# 15net_house_w_child 0.15803765851
# 15net_hunits_detached 0.0212567668953
# 15net_pop_child 0.0114496297809
# 15net_pop_poor 0.00241006586302
# 30net_hunits_detached 0.00699243835632
# Lowest in cluster, dropping:  15net_pop_poor 0.00241006586302
# Cluster
# 30net_business 0.000399915270499
# 30net_emp_pay 0.0518879401839
# 30net_employment 0.000511890577788
# 30net_entertainment 0.000869912047286
# 30net_finance 0.000446191020086
# 30net_hospitality 0.00118486931602
# Lowest in cluster, dropping:  30net_business 0.000399915270499
# Cluster
# 30net_bachelors 0.000453827870282
# 30net_emp_full_time 0.00025939884836
# 30net_employed 0.000631170534706
# 30net_family 0.000554119910884
# 30net_house_w_child 0.00167794400754
# 30net_household 0.000120396553266
# 30net_hunits 0.00021282779811
# 30net_hunits_attached 3.85973033377e-05
# 30net_hunits_large 0.000863467935567
# 30net_hunits_medium 0.00159846682699
# 30net_hunits_new 0.000579948613805
# 30net_hunits_old 0.000175959303181
# 30net_hunits_owner 0.00929581374045
# 30net_hunits_renter 0.000701687228878
# 30net_hunits_vacant 0.000696631033909
# 30net_labor_force 0.00115695687503
# 30net_pop_child 0.00112397544859
# 30net_pop_old 8.08380000101e-05
# 30net_pop_poor 0.0440249075213
# 30net_pop_rich 0.000261390155172
# 30net_population 9.16162877068e-05
# Lowest in cluster, dropping:  30net_hunits_attached 3.85973033377e-05
# Cluster
# 15net_medical 0.0112062046114
# 15net_university 0.00221751657453
# 30net_medical 0.0156408104047
# 30net_university 0.0101654509011
# 60net_medical 0.00410247815386
# 60net_university 0.00153182632407
# Lowest in cluster, dropping:  60net_university 0.00153182632407
# Cluster
# 60net_bachelors 4.20954257708e-06
# 60net_business 2.28250369754e-05
# 60net_emp_pay 4.70283396942e-05
# 60net_employment 0.000172001099058
# 60net_finance 2.67771965063e-05
# 60net_hospitality 0.000178487561118
# 60net_hunits_attached 0.000180742829244
# 60net_hunits_medium 1.60890043479e-05
# 60net_hunits_new 0.00688042104778
# 60net_hunits_old 0.00141301797323
# 60net_hunits_owner 0.000346771218973
# 60net_hunits_vacant 0.00357728473912
# 60net_pop_rich 0.000308314972016
# Lowest in cluster, dropping:  60net_bachelors 4.20954257708e-06
# Cluster
# 60net_emp_full_time 0.000170038575493
# 60net_employed 2.62170630842e-05
# 60net_entertainment 0.000441733780347
# 60net_family 4.28572235306e-06
# 60net_house_w_child 0.000177900058223
# 60net_household 5.49611242218e-06
# 60net_hunits 1.90086847834e-05
# 60net_hunits_detached 0.00341541584578
# 60net_hunits_large 0.000763453670342
# 60net_hunits_renter 2.07502150098e-05
# 60net_labor_force 0.000430772140567
# 60net_pop_child 0.00215792540033
# 60net_pop_old 0.000384208317424
# 60net_pop_poor 0.00205952570561
# 60net_population 4.28279767561e-06
# Lowest in cluster, dropping:  60net_population 4.28279767561e-06
# Cluster
# near_business 0.0105114703677
# near_emp_pay 0.000846793668291
# near_employment 0.0114337453296
# near_entertainment 0.00251264667321
# near_finance 0.00381337100484
# near_hospitality 0.0043664876644
# Lowest in cluster, dropping:  near_emp_pay 0.000846793668291
# Cluster
# near_family 0.00122461758756
# near_house_w_child 0.00594731766932
# near_pop_child 0.000761231916508
# near_pop_poor 0.00477410308792
# near_population 0.00678073211383
# Lowest in cluster, dropping:  near_pop_child 0.000761231916508
# Cluster
# near_emp_full_time 0.0063086294727
# near_employed 0.00122231083983
# near_household 0.00230384316857
# near_hunits 0.00494009812474
# near_hunits_large 0.00259018074271
# near_hunits_renter 0.00706439727224
# near_hunits_vacant 0.00474006833596
# near_labor_force 0.0130026736534
# near_pop_old 0.00710562220585
# Lowest in cluster, dropping:  near_employed 0.00122231083983
# Cluster
# near_hunits_detached 0.000586081957908
# walk_hunits_detached 0.0240671317146
# Lowest in cluster, dropping:  near_hunits_detached 0.000586081957908
# Cluster
# near_hunits_attached 0.00152596923762
# near_hunits_medium 0.0020318070152
# near_hunits_old 0.000226068822259
# walk_hunits_attached 0.019168823596
# Lowest in cluster, dropping:  near_hunits_old 0.000226068822259
# Cluster
# near_bachelors 0.0280472130754
# near_hunits_new 0.000965175507313
# near_hunits_owner 0.00753422466278
# near_pop_rich 0.00219197880104
# Lowest in cluster, dropping:  near_hunits_new 0.000965175507313
# Cluster
# walk_business 0.000834046061923
# walk_emp_pay 0.00511808444909
# walk_employment 0.000728641336383
# walk_entertainment 0.000187059596363
# walk_finance 0.00469817950154
# walk_hospitality 0.0167291768833
# walk_hunits_new 0.00152884048958
# Lowest in cluster, dropping:  walk_entertainment 0.000187059596363
# Cluster
# walk_bachelors 0.000635957141764
# walk_emp_full_time 0.00157215453411
# walk_employed 0.000162758123103
# walk_family 0.00128518821863
# walk_household 0.00327570583731
# walk_hunits 8.54293845261e-05
# walk_hunits_large 0.000284416833168
# walk_hunits_medium 0.000194517473
# walk_hunits_old 0.00136672192358
# walk_hunits_owner 0.0026318259231
# walk_hunits_renter 0.00321897898537
# walk_hunits_vacant 0.000640219510399
# walk_labor_force 0.00156482269051
# walk_pop_old 0.00174462683555
# walk_pop_rich 0.000210666710397
# walk_population 0.000956969034802
# Lowest in cluster, dropping:  walk_hunits 8.54293845261e-05
# Cluster
# near_medical 0.00167725964102
# near_university 0.00651661242242
# walk_medical 0.0153267467768
# walk_university 0.00583891382203
# Lowest in cluster, dropping:  near_medical 0.00167725964102
# Cluster
# walk_house_w_child 0.00875420770478
# walk_pop_child 0.000949906715382
# walk_pop_poor 0.00869952627548
# Lowest in cluster, dropping:  walk_pop_child 0.000949906715382
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     726             try:
# --> 727                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     728             except Exception:
#
# /usr/local/lib/python3.5/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.5/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.5/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-db71421e6439> in <module>()
# ----> 1 choose_best()
#
# <ipython-input-6-9730582bf1fa> in choose_best()
#      50         rcols, radj = remove_cols(to_remove, rcols, radj)
#      51
# ---> 52         input() # Remove
#      53
#      54
#
# /usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     700             self._parent_ident,
#     701             self._parent_header,
# --> 702             password=False,
#     703         )
#     704
#
# /usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     730             except KeyboardInterrupt:
#     731                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 732                 raise KeyboardInterrupt
#     733             else:
#     734                 break
#
# KeyboardInterrupt:

# %%
totalcounts = {}
for i in range(10):
    print("Iteration: {0}\r".format(i+1))
    selects = choose_best() 
    for name in selects:
        if name in totalcounts:
            totalcounts[name] += 1
        else:
            totalcounts[name] = 1
            
countlist = sorted([(name, count) for name, count in totalcounts.items()], key=lambda x:x[1], reverse=True)
for name, count in countlist:
    print("{0}: {1}%".format(name, count))
# Out:
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# 15net_hunits_detached: 10%
# parking: 10%
# near_university: 8%
# walk_hunits_detached: 7%
# near_medical: 6%
# near_employment: 6%
# walk_pop_old: 6%
# 15net_house_w_child: 6%
# walk_hunits_attached: 6%
# near_hunits_new: 5%
# 15net_university: 4%
# near_household: 4%
# near_hospitality: 4%
# walk_business: 3%
# near_bachelors: 3%
# near_hunits_detached: 3%
# near_entertainment: 3%
# 15net_business: 2%
# near_hunits_owner: 2%
# 60net_emp_pay: 2%
# 15net_family: 2%
# walk_university: 2%
# 15net_population: 2%
# near_hunits_vacant: 1%
# 60net_hospitality: 1%
# 60net_university: 1%
# 60net_entertainment: 1%
# walk_pop_poor: 1%
# walk_hunits: 1%
# 30net_emp_pay: 1%
# 60net_family: 1%
# walk_population: 1%
# near_labor_force: 1%
# walk_pop_child: 1%
# 30net_university: 1%
# 60net_hunits_detached: 1%

# %%
selects
# Out:
# ['parking',
#  'near_entertainment',
#  '15net_hunits_detached',
#  'walk_hunits_detached',
#  'near_employment',
#  'walk_medical',
#  'near_hunits_vacant',
#  'walk_pop_poor',
#  '30net_university',
#  'walk_hunits_attached',
#  'near_hunits_owner',
#  '15net_house_w_child',
#  '15net_business']

# %%
# Out:
# [0 1 0 1 2 1 1 0]
